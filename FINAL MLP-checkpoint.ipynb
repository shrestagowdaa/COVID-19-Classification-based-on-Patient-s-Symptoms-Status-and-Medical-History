# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/DATA/Covid Data.csv"
df = pd.read_csv(path)
df.head(5)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1    3/5/2020       97          1
# 1      2             1    2             1    3/6/2020       97          1
# 2      2             1    2             2    9/6/2020        1          2
# 3      2             1    1             1   12/6/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
# Printing shape of dataframe
df.shape
# Out:
# (1048575, 21)

# %%
df.isna().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
# Checking data types of features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
# Calculating descriptive statistics of numerical features
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
# Plotting each feature using histogram
df.hist(figsize=(20,20));

# %%
# Checking the number of identical records
df.duplicated().sum()
# Out:
# 812049

# %%
df = df.drop_duplicates()
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1    3/5/2020       97
# 1            2             1    2             1    3/6/2020       97
# 2            2             1    2             2    9/6/2020        1
# 3            2             1    1             1   12/6/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048568      1            13    2             1  9999-99-99       97
# 1048569      1            13    1             2  9999-99-99        2
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
# Resetting index
df.reset_index(drop=True, inplace=True)
df=df.dropna()

# %%
# Chosing target feature
target = "CLASIFFICATION_FINAL"

# Splitting data
X = df.drop(target, axis=1)
y = df[target]

# Printing X
X
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0           2             1    1             1    3/5/2020       97
# 1           2             1    2             1    3/6/2020       97
# 2           2             1    2             2    9/6/2020        1
# 3           2             1    1             1   12/6/2020       97
# 4           2             1    2             1  21/06/2020       97
# ...       ...           ...  ...           ...         ...      ...
# 236521      1            13    2             1  9999-99-99       97
# 236522      1            13    1             2  9999-99-99        2
# 236523      1            13    2             2  9999-99-99        2
# 236524      2            13    2             1  9999-99-99       97
# 236525      2            13    2             1  9999-99-99       97
#
#         PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  \
# 0               1   65         2         2     2       2        2
# ...

# %%
y
# Out:
# 0         3
# 1         5
# 2         3
# 3         7
# 4         3
#          ..
# 236521    7
# 236522    7
# 236523    7
# 236524    7
# 236525    7
# Name: CLASIFFICATION_FINAL, Length: 236526, dtype: int64

# %%
X["DATE_DIED"].value_counts()
# Out:
# 9999-99-99    160561
# 7/7/2020         984
# 6/7/2020         980
# 13/07/2020       970
# 16/06/2020       960
#                ...
# 24/11/2020         1
# 17/12/2020         1
# 8/12/2020          1
# 16/03/2021         1
# 22/04/2021         1
# Name: DATE_DIED, Length: 401, dtype: int64

# %%
# Calculating percent of missing data
X["DATE_DIED"].value_counts()[0] / X["DATE_DIED"].value_counts().sum()
# Out:
# 0.678830234308279

# %%
X.drop("DATE_DIED", axis=1, inplace=True)

# Printing data
X.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  PREGNANT  \
# 0      2             1    1             1       97          1   65         2
# 1      2             1    2             1       97          1   72        97
# 2      2             1    2             2        1          2   55        97
# 3      2             1    1             1       97          2   53         2
# 4      2             1    2             1       97          2   68        97
#
#    DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2     2       2        2             1              2
# 1         2     2       2        2             1              2
# 2         1     2       2        2             2              2
# 3         2     2       2        2             2              2
# 4         1     2       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  ICU
# 0               2        2              2        2   97
# ...

# %%
y.value_counts()
# Out:
# 3    106712
# 7     77075
# 6     33629
# 5     10900
# 1      4730
# 2      1846
# 4      1634
# Name: CLASIFFICATION_FINAL, dtype: int64

# %%
# Transforming multiclass CLASIFFICATION_FINAL feature into binary feature
y = y.apply(lambda x: 1 if x <= 3 else 0)

# Printing target feature value counts
y.value_counts()
# Out:
# 0    123238
# 1    113288
# Name: CLASIFFICATION_FINAL, dtype: int64

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Calcualting % of classes in target features
percantages = np.round(y.value_counts() / X.shape[0], 2)

# Barplot
sns.barplot(x=y, y=percantages);

# %%
from imblearn.under_sampling import RandomUnderSampler

# RandomUnderSampler
X, y = RandomUnderSampler().fit_resample(X, y)

# Resetting index
df.reset_index(drop=True, inplace=True)

# Barplot
sns.countplot(x=y);

# %%
# Getting all discrete type features
categorical_features = X.select_dtypes(include = "int64").columns.drop("AGE")

# Printing all discrete features
categorical_features
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA',
#        'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION',
#        'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC',
#        'TOBACCO', 'ICU'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Trasforming features using LabelEncoder
X[categorical_features] = df[categorical_features].apply(LabelEncoder().fit_transform)

# Prting new features
X
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           1             0    0             0        2          0   54
# 1           1             0    1             0        2          0   53
# 2           1             0    1             1        0          1   25
# 3           1             0    0             0        2          1   50
# 4           1             0    1             0        2          1   46
# ...       ...           ...  ...           ...      ...        ...  ...
# 226571      1            11    0             0        2          1   67
# 226572      1            11    1             0        2          1   77
# 226573      0            11    0             0        2          1   70
# 226574      1            11    1             1        1          0   32
# 226575      0            11    0             1        1          1   30
#
#         PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  \
# ...

# %%
from sklearn.preprocessing import RobustScaler

# Scaling feature
X["AGE"] = RobustScaler().fit_transform(X[["AGE"]])

# Printing new feature
X.AGE
# Out:
# 0         0.000000
# 1        -0.037037
# 2        -1.074074
# 3        -0.148148
# 4        -0.296296
#             ...
# 226571    0.481481
# 226572    0.851852
# 226573    0.592593
# 226574   -0.814815
# 226575   -0.888889
# Name: AGE, Length: 226576, dtype: float64

# %%
X.hist(figsize=(20,20));

# %%
# Creating copy of X data
full_data = X.copy()

# Adding target column to copy of X
full_data["target"] = y

# Computing the correlation matrix
corr_matrix = np.round(np.corrcoef(full_data, rowvar=False), 2)

# Plotting the correlation matrix
plt.figure(figsize=(14,11))
sns.heatmap(corr_matrix, cmap='viridis', annot=True,
            xticklabels=full_data.columns, yticklabels=full_data.columns
           )
plt.title("Correlation Matrix");

# %%
from sklearn.decomposition import PCA


# Transforming data into 2dim using PCA
pca = PCA(2)
pca_data = pca.fit_transform(X)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# Evaluating SVM model using Bootstraping method
scores = cross_val_score(SVC(), X, y)

# Calculating mean of scores
scores.mean()
# Out:
# 0.8846705996111389

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Evaluating GradientBoostingClassifier model using Bootstraping method
scores = cross_val_score(GradientBoostingClassifier(), X, y)

# Calculating mean of scores
scores.mean()
# Out:
# 0.9039887061983617

# %%
from sklearn.ensemble import RandomForestClassifier
# Evaluating the model using cross-validation
scores = cross_val_score(RandomForestClassifier(), X, y)
scores.mean()
# Out:
# 0.9039887061983617

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
scores = cross_val_score(LogisticRegression(), X, y)
scores.mean()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Create instances of the models
lr_model = LogisticRegression()

# Perform cross-validation and obtain predicted labels
lr_pred = cross_val_predict(lr_model, X, y)

# Calculate confusion matrix
cm = confusion_matrix(y, lr_pred)
print("Confusion Matrix:")
print(cm)

# Calculate accuracy
accuracy = accuracy_score(y, lr_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y, lr_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y, lr_pred)
print("Recall:", recall)

# Calculate F1 score
f1 = f1_score(y, lr_pred)
print("F1 Score:", f1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Create instances of the models
lr_model = RandomForestClassifier()

# Perform cross-validation and obtain predicted labels
lr_pred = cross_val_predict(lr_model, X, y)

# Calculate confusion matrix
cm = confusion_matrix(y, lr_pred)
print("Confusion Matrix:")
print(cm)

# Calculate accuracy
accuracy = accuracy_score(y, lr_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y, lr_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y, lr_pred)
print("Recall:", recall)

# Calculate F1 score
f1 = f1_score(y, lr_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[102460  10828]
#  [ 10926 102362]]
# Accuracy: 0.9039880658145611
# Precision: 0.9043378390317166
# Recall: 0.9035555398630041
# F1 Score: 0.9039465201918068

# %%
# Create instances of the models
lr_model = GradientBoostingClassifier()

# Perform cross-validation and obtain predicted labels
lr_pred = cross_val_predict(lr_model, X, y)

# Calculate confusion matrix
cm = confusion_matrix(y, lr_pred)
print("Confusion Matrix:")
print(cm)

# Calculate accuracy
accuracy = accuracy_score(y, lr_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y, lr_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y, lr_pred)
print("Recall:", recall)

# Calculate F1 score
f1 = f1_score(y, lr_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[102460  10828]
#  [ 10926 102362]]
# Accuracy: 0.9039880658145611
# Precision: 0.9043378390317166
# Recall: 0.9035555398630041
# F1 Score: 0.9039465201918068

# %%
# Create instances of the models
lr_model = SVC()

# Perform cross-validation and obtain predicted labels
lr_pred = cross_val_predict(lr_model, X, y)

# Calculate confusion matrix
cm = confusion_matrix(y, lr_pred)
print("Confusion Matrix:")
print(cm)

# Calculate accuracy
accuracy = accuracy_score(y, lr_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y, lr_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y, lr_pred)
print("Recall:", recall)

# Calculate F1 score
f1 = f1_score(y, lr_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[ 98083  15205]
#  [ 10926 102362]]
# Accuracy: 0.8846700444883836
# Precision: 0.8706694905883454
# Recall: 0.9035555398630041
# F1 Score: 0.8868077364579499

# %%
from sklearn.tree import DecisionTreeRegressor
lr_model = DecisionTreeRegressor()

# Perform cross-validation and obtain predicted labels
lr_pred = cross_val_predict(lr_model, X, y)

# Calculate confusion matrix
cm = confusion_matrix(y, lr_pred)
print("Confusion Matrix:")
print(cm)

# Calculate accuracy
accuracy = accuracy_score(y, lr_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y, lr_pred)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y, lr_pred)
print("Recall:", recall)

# Calculate F1 score
f1 = f1_score(y, lr_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[113288      0]
#  [ 10170 103118]]
# Accuracy: 0.9551143987006567
# Precision: 1.0
# Recall: 0.9102287974013135
# F1 Score: 0.9530049998613717
